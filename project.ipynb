# %%
import pandas as pd
df=pd.read_csv("mart.csv")            # reads the csv file
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df.shape                                # tells no. of rows and columns
# Out:
# (8523, 12)

# %%
df.describe(include=['object','bool'])
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDG33          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.info()                                    # tells how much are filled values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
df.isnull().sum()                               # counts the missing values
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# 5               False        False             False            False
# 6               False        False             False            False
# 7               False         True             False            False
# 8               False        False             False            False
# 9               False        False             False            False
# 10              False        False             False            False
# 11              False        False             False            False
# ...

# %%
df.fillna(df.median())                      # fill the missing values with median
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10       12.600          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
import pandas as pd
df=pd.read_csv("mart.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
import seaborn as sns
sns.distplot(df["Item_Visibility
"])
# Out:
# C:\Users\smaily\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
f=['Item_Weight']
df[f].hist(figsize=(10,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DAB864CBE0>]],
#       dtype=object)

# %%
f=['Item_MRP']
df[f].hist(figsize=(12,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DAB86B2898>]],
#       dtype=object)

# %%
sns.distplot(df['Item_MRP'])
# Out:
# C:\Users\smaily\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import matplotlib as plt
sns.boxplot(data=df['Outlet_Establishment_Year'])

# %%
sns.boxplot(data=df['Item_Visibility'])

# %%
import seaborn as sns
import pandas as pd
df=pd.read_csv("mart.csv") 
sns.countplot(df['Item_MRP'])

# %%
pd.crosstab(df['Item_Weight'],df['Outlet_Size'],margins=True)
# Out:
# Outlet_Size  High  Medium  Small   All
# Item_Weight
# 4.555           1       1      2     4
# 4.59            1       1      2     4
# 4.61            0       2      2     4
# 4.615           1       0      1     2
# 4.635           0       1      2     3
# 4.785           1       1      1     3
# 4.805           1       1      1     3
# 4.88            1       2      1     4
# 4.905           0       0      1     1
# 4.92            1       2      1     4
# 5.0             0       0      1     1
# 5.03            1       0      1     2
# 5.035           1       0      1     2
# 5.095           1       2      1     4
# 5.11            0       1      2     3
# 5.15            1       1      2     4
# 5.155           0       1      1     2
# 5.175           3       3      4    10
# 5.19            0       3      1     4
# 5.21            0       0      1     1
# 5.26            0       3      1     4
# 5.305           0       2      0     2
# 5.32            1       2      1     4
# ...

# %%
sns.countplot(x='Item_Weight',hue='Outlet_Size',data=df)

# %%
sns.jointplot(x='Item_Visibility',y='Item_MRP',data=df)\
# Out:
# C:\Users\smaily\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\smaily\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("mart.csv")  
sns.pairplot(df,hue='Item_Outlet_Sales')

# %%
sns.lmplot(x='Item_Visibility',y='Item_MRP',data=df,hue='Item_Outlet_Sales',fit_reg=False)

# %%
sns.heatmap(df.corr())

# %%
sns.boxplot(x='Item_Outlet_Sales',y='Item_MRP',data=df)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("mart.csv")  
sns.heatmap(df.corr())

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("mart.csv")  
from sklearn.feature_selection import VarianceThreshold
selector= VarianceThreshold(0.5)
selector.fit_transform(df["Item_Weight "]["Outlet_Size"]["Item_Visibility"]["Item_MRP"]["Item_Outlet_Sales"])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("mart.csv")  
from sklearn.feature_selection import VarianceThreshold
selector= VarianceThreshold(0.5)
selector.fit_transform(df["Item_Weight "]["Outlet_Size"]["Item_Visibility"]["Item_MRP"]["Item_Outlet_Sales"])

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X,y=df.data,df.target
X_new= SelectKBest(chi2, k=2).fit_transform(X,y)
X.shape,X_new.shape

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
regressor= LinearRegression()
X=dataset[['Item_Weight','Item_Visibility','Item_MRP','Item_Outlet_Sales','Outlet_Establishment_Year']]
y=dataset[['Item_Outlet_Sales']]
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.5,random_state=0)
regressor.fit(X_train,y_train)

# %%
regressor.intercept_

# %%
regressor.coef_

# %%
y_pred=regressor.predict(X_test)

# %%
df=pd.Dataframe({'Actual':y_test, 'Predicted':y_pred})
df

# %%
import numpy as np
from sklearn import metrics
print("Mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared error:",metrics.mean_squared_error(y_test,y_pred))
print(" Root Means squared error:",np.sqrt(metrics.mean_absolute_error(y_test,y_pred)))
